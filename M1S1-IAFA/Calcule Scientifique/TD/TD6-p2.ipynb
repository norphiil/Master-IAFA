# %% [markdown]
# ---------------------------------------------------------------------------
# Exercice 2 : Approximations linéaire et non linéaire
# ---------------------------------------------------------------------------
# Partie B : Approximation non linéaire
# $$
# f(0) = 1
# \\
# f(1) = 3
# \\
# f(2) = 7
# \\
# g(x) = a ~\sqrt{|x-1|} + bx^2
# \\
# ----1----
# \\
# g(0) = a = 1
# \\
# g(1) = b = 3
# \\
# g(2) = a + 4b = 1 + 12 = 13 \ne 7
# \\
# ----2----
# \\
# S(a, b) = \sum_{i=1}^{3} (y_i - g(x_i))^2 = (1 - a)^2 + (3 - b)^2 + (7 - (a + 4b))^2
# \\
# CN ~1^{er} ~ordre
# \\
# \nabla S(a, b) =
# \begin{pmatrix}
# 0 \\
# 0
# \end{pmatrix}
# \iff
# \begin{cases}
# 2(1 - a) + 2(7 - (a + 4b)) = 0 \\
# 2(3 - b) + 8(7 - (a + 4b)) = 0
# \end{cases}
# \iff
# \begin{cases}
# 1 - a + 7 - a - 4b = 0 \\
# 3 - b + 28 - 4a - 16b = 0
# \end{cases}
# \\
#
# \begin{cases}
# a + 2b = 4 \\
# 4a + 17b = 31
# \end{cases}
# \\
# \begin{cases}
# 4a + 17b = 31 \\
# 4a + 17b = 31
# \end{cases}
# \iff
# 0 - 9b = -15
# \\
# b = \frac{5}{3}
# \\
# d = 4 - 2b = 4 - \frac{10}{3} = \frac{2}{3}
# $$

# %% [markdown]
# -----------------------------------------------------------------------------------------------
# Formulation factoriser
# $$
# g(x) = a ~\sqrt{|x-1|} + bx^2
# \\
# = \begin{pmatrix} u & v \end{pmatrix} \begin{pmatrix} a \\ b \end{pmatrix}
# \\
# = a ~u + b ~v
# \\
# Par ~identification \begin{cases} u = \sqrt{|1-x|} \\ v = x^2 \end{cases}
# \\
# g(x) = \begin{pmatrix} \sqrt{|1-x|} & x^2 \end{pmatrix} \begin{pmatrix} a \\ b \end{pmatrix}
# \\
# On ~applique ~aux ~données ~dont ~on ~dispose :
# \\
# A = \begin{pmatrix} \sqrt{|1-0|} & 0^2 \\ \sqrt{|1-1|} & 1^2 \\ \sqrt{|1-2|} & 2^2 \end{pmatrix}
# \\
# b = \begin{pmatrix} 1 \\ 3 \\ 7 \end{pmatrix}
# \\
# Min S(a, b) = Min ||A\beta - b||^2
# \\
# \beta =  \begin{pmatrix} a \\ b \end{pmatrix}
# \\
# \beta = (A^TA)^{-1}A^Tb
# \\
# A^TA = \begin{pmatrix} 2 & 4 \\ 4 & 17 \end{pmatrix}
# \\
# (a, b) =  \begin{pmatrix} \frac{2}{3}, \frac{5}{3} \end{pmatrix}
# \\
# A^Tb = \begin{pmatrix} 1 & 0 & 1 \\ 0 & 1 & 4 \end{pmatrix} \begin{pmatrix} 1 \\ 3 \\ 7 \end{pmatrix} = \begin{pmatrix} 8 \\ 31 \end{pmatrix}
# \\
# (A^TA)^{-1}A^Tb = \frac{1}{18} \begin{pmatrix} 17 & -4 \\ -4 & 2 \end{pmatrix} \begin{pmatrix} 8 \\ 31 \end{pmatrix}
# \\
# = \begin{pmatrix} \frac{12}{18} \\ \frac{30}{18} \end{pmatrix} = \begin{pmatrix} \frac{2}{3} \\ \frac{5}{3} \end{pmatrix}
# $$

# %% [markdown]
# -----------------------------------------------------------------------------------------------
# Exercice 3 : Moodelisation d'une réaction chimique par la methode des moindres carrés.
# -----------------------------------------------------------------------------------------------
# $$
# \frac{dC(t)}{dt} = -\lambda C(t) \\
# C(t) = C_0 e^{-\lambda t} \\
# (C_0 e^{-\lambda t})' + \lambda(C_0 e^{-\lambda t}) = -\lambda C_0 e^{-\lambda t} + \lambda C_0 e^{-\lambda t} = 0 \\
# ----1----
# Justifier ~que ~\lambda > 0
# \\
# \lambda > 0 ~car ~les ~concentrations ~decroitent ~en ~fonction ~du ~temps ~t ~donc ~t ~|-> e^{-\lambda t} ~doit ~étre ~strictement ~decroissant.
# \\
# ----2----
# \\
# Ecrire ~le ~probléme ~d'optimisation ~aux ~moindres ~carrés ~non ~linéaires.
# \\
# S(C_0, \lambda) = \frac{1}{6}\sum_{i=1}^{6} (C(T_i) - C_0e^{-\lambda T_i})^2
# \\
# ----3----
# \\
# Ecrire ~le ~problème ~sous ~forme ~d'un ~problème ~d'optimisation ~aux ~moindres ~carrés ~linéaires.
# \\
# ln C(t) = ln C_0 - \lambda t = \begin{pmatrix} u & v \end{pmatrix} \begin{pmatrix} ln C_0 \\ \lambda \end{pmatrix}
# \\
# u ~ln (C_0) + v \lambda
# \\
#
#
#
# $$

# %% [markdown]
# -----------------------------------------------------------------------------------------------
# Exercice 8 : Calcul de la position d'un utilisateur avec le GPS.
# -----------------------------------------------------------------------------------------------
# $$
# ----1----
# \\
# Soient ~P_i = [x_i, y_i, z_i]^T ~les ~positions ~des ~satellites ~visibles ~et ~P_u = [x_u, y_u, z_u]^T ~la ~position ~de ~l'utilisateur ~a ~déterminer. \\
# Calculer ~la ~distance ~qui ~sépare ~les ~satellites ~de ~l'utilisateur.
# \\
# d = v * t = c((t_{ui} - \tau) - t_i) = ||P_u - P_i||
# \\
# Min ~R(\beta) = (||P_u - P_i|| - c((t_{ui} - \tau) - t_i))^2
# $$

# %% [markdown]
# -----------------------------------------------------------------------------------------------
# Exercice 4 : Opérations géométriques 2D.
# -----------------------------------------------------------------------------------------------
# $$
# ----1----
# \\
# \begin{cases}
# x' = x + \alpha y \\
# y' = y\beta + x
# \end{cases}
# \\
# \begin{bmatrix} x' \\ y' \end{bmatrix} = \begin{bmatrix} 1 & \alpha \\ \beta & 1 \end{bmatrix} \begin{bmatrix} x \\ y \end{bmatrix}
# \\
# \gamma = \begin{bmatrix} \alpha \\ \beta  \end{bmatrix}
# \\
# \begin{cases}
# x' = x + \alpha y \\
# y' = y\beta + x
# \end{cases}
# \iff
# \begin{cases}
# x' - x = \alpha y \\
# y' - y = \beta x
# \end{cases}
# \\
# \begin{bmatrix} x' - x \\ y' - y \end{bmatrix} = \begin{bmatrix} y & 0 \\ 0 & x \end{bmatrix} \begin{bmatrix} \alpha \\ \beta \end{bmatrix}
# \\
# Min ~||A\gamma - b||^2 ~avec \\
# A = \begin{bmatrix} y_1 & 0 \\ ... & ... \\ y_n & 0 \\ 0 & x_1 \\ ... & ... \\ 0 & x_n \end{bmatrix}
# \\
# b = \begin{bmatrix} x_1' - x_1 \\ ... \\ x_n'  - x_n \\ y_1' - y_1 \\ ... \\ y_n - y_n \end{bmatrix}
# \\
# \gamma = (A^TA)^{-1}A^Tb
# \\
# A^TA = \begin{bmatrix} \sum_{i=1}^{n} y_i^2 & 0 \\ 0 & \sum_{i=1}^{n} x_i^2 \end{bmatrix}
# \\
# (A^TA)^{-1} = \begin{bmatrix} \frac{1}{\sum_{i=1}^{n} y_i^2} & 0 \\ 0 & \frac{1}{\sum_{i=1}^{n} x_i^2} \end{bmatrix}
# \\
# A^Tb = \begin{bmatrix} \sum_{i=1}^{n} y_i(x_i' - x_i) \\ \sum_{i=1}^{n} x_i(y_i' - y_i) \end{bmatrix}
# \\
# \gamma = \begin{bmatrix} \frac{\sum_{i=1}^{n} y_i(x_i' - x_i)}{\sum_{i=1}^{n} y_i^2} \\ \frac{\sum_{i=1}^{n} x_i(y_i' - y_i)}{\sum_{i=1}^{n} x_i^2} \end{bmatrix}
# $$
